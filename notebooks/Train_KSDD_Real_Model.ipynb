# %% [markdown]
# # ForgeMind AI · KSDD Real Training
# KSDD is non-commercial unless permission is obtained.

# %%
from google.colab import files
uploaded=files.upload()

# %%
# !unzip -q ForgeMind_AI.zip -d /content/forgemind
# %cd /content/forgemind/ForgeMind_AI
# !pip -q install -r backend/requirements.txt

# %%
# !python backend/ml/download_real_datasets.py ksdd --accept-ksdd-nc-license
# !find backend/ml/data/ksdd -maxdepth 3 -type d | head

# %%
# !python backend/ml/train_ksdd.py backend/ml/data/ksdd

# %%
# !zip -j /content/ksdd_model_artifacts.zip backend/ml/models/quality_inspector.* backend/ml/reports/quality/*
files.download('/content/ksdd_model_artifacts.zip')
